# %%
import pandas as pd

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler

import torch
from torch.utils.data import Dataset, DataLoader

# %%
data = pd.read_csv('dataset/diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# `Blood Pressure` is 0 for some values which indicates that the data is tampered

# %%
# Checking for class balance/ imbalance
data['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
# Split data into training and testing
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.4,random_state=7)
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values
for train_idx, test_idx in sss.split(x,y):
    x_train,group_x = x[train_idx], x[test_idx]
    y_train,group_y = y[train_idx],y[test_idx]
    
x_train.shape,group_x.shape
# Out:
# ((460, 8), (308, 8))

# %%
# Further splitting the data into Validation and testing
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.5,random_state=7)

for test_idx, val_idx in sss.split(group_x,group_y):
    x_test,x_val = x[test_idx], x[val_idx]
    y_test, y_val = y[test_idx],y[val_idx]

x_val.shape, x_test.shape
# Out:
# ((154, 8), (154, 8))

# %%
# Perform Data Standardization
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_valid = scaler.transform(x_val)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_valid = x_valid.astype('float32')

# %%
# Building the Model
x_train,x_test,x_valid = map(torch.tensor,(x_train,x_test,x_valid))
y_train,y_test,y_valid = map(torch.tensor,(y_train,y_test,y_val))

# %%
class Diabetes(Dataset):
    
    def __init__(self,x,y):
        self.x = x
        self.y = y
        pass
    
    def __getitem__(self,index):
        return self.x[index], self.y[index]
    
    def __len__(self):
        return len(self.x)

# %%
data = Diabetes(x_train,y_train)
valid_Data = Diabetes(x_valid, y_valid)
train_loader = DataLoader(dataset = data, batch_size = 16)

# %%
class DiabetesPredictorNN(torch.nn.Module):
    def __init__(self,n_inputs, n_outputs, hidden_size):
        super(DiabetesPredictorNN, self).__init__()
        self.n_inputs = n_inputs
        self.n_outputs = n_outputs
        self.hidden_size = hidden_size
        
        self.fc1 = torch.nn.Linear(self.n_inputs, self.hidden_size)
        self.fc2 = torch.nn.Linear(self.hidden_size, self.hidden_size)
        self.fc3 = torch.nn.Linear(self.hidden_size, self.n_outputs)
        
        self.relu = torch.nn.ReLU()
        
        self.initialize_weights()
        
    def initialize_weights(self):
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        torch.nn.init.kaiming_normal_(self.fc2.weight)
        torch.nn.init.kaiming_normal_(self.fc3.weight)
        
        
    def forward(self, features):
        output = self.fc1(features)
        output = self.relu(output)
        
        output = self.fc2(output)
        output = self.relu(output)
        
        output = self.fc3(output)
        return output

# %%
model = DiabetesPredictorNN(n_inputs = x_train.shape[1], n_outputs = 2, hidden_size=10)
# Criterion is for loss
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.001)

# %%
epochs = 50   # Low learning rate should be complimented with large number of epochs
patience = 3
valid_accuracy_list = []

for epoch in range(epochs):
    for features, targets in train_loader:
        output = model.forward(features)
        loss = criterion(output, targets)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # Each epoch: eval on the train set
    model.eval()
    c = torch.argmax(output.data, dim=1)
    train_accuracy = (c==targets).sum().item() / targets.shape[0]
    
    # Eval for validation dataset
    hpy = model.forward(x_valid)
    c = torch.argmax(hpy.data,dim=1)
    valid_accuracy = (c == y_valid).sum().item() / x_valid.shape[0]
    
    valid_accuracy_list.append(valid_accuracy)
    
    
    if (patience>=0):
        if len(valid_accuracy_list) >= 1 and valid_accuracy == valid_accuracy_list[epoch-1]:
            patience -= 1  
        else:
            patience = 3 
    else:
        print("Accuracy is not Improving!!!")     
        break
            
    
    print("Epoch : {}, Training Accuracy : {} Validation Accuracy : {}".format(epoch,train_accuracy,valid_accuracy))
# Out:
# Epoch : 0, Training Accuracy : 0.6666666666666666 Validation Accuracy : 0.7597402597402597
# Epoch : 1, Training Accuracy : 0.6666666666666666 Validation Accuracy : 0.7597402597402597
# Epoch : 2, Training Accuracy : 0.6666666666666666 Validation Accuracy : 0.7597402597402597
# Epoch : 3, Training Accuracy : 0.6666666666666666 Validation Accuracy : 0.7597402597402597
# Accuracy is not Improving!!!

# %%
# Test

# Turn off learning
with torch.no_grad():
    test_hyp = model.forward(x_test)
    c = torch.argmax(test_hyp.data, dim=1)
    test_acc = (c==y_test).sum().item() / y_test.shape[0]
    print("Accuarcy on Test Data : {:.2f}".format(test_acc))
# Out:
# Accuarcy on Test Data : 0.67
